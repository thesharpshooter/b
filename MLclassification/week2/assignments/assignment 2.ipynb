# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
products = pd.read_csv('../data/amazon_baby_subset.csv')
important_words = list(pd.read_json('../data/important_words.json')[0])
train_id = pd.read_json('../data/module-4-assignment-train-idx.json')
validation_id = pd.read_json('../data/module-4-assignment-validation-idx.json')

# %%
print list(products)
# Out:
# ['name', 'review', 'rating', 'sentiment']

# %%
products = products.fillna({'review':''})

# %%
def remove_punctuation(word):
    import string
    return word.translate(None,string.punctuation)

# %%
products['review_clean'] = products['review'].apply(remove_punctuation)

# %%
for word in important_words:
    products[word] = products['review_clean'].apply(lambda x: x.split(" ").count(word))

# %%
data_train = products.ix[list(train_id[0])]
data_validation = products.ix[list(validation_id[0])]

# %%
def get_numpy_data(data_frame,features,sentiment):
    data_frame['ones'] = 1
    features = ['ones'] + features
    feature_matrix = data_frame[features].as_matrix()
    sentiment_matrix = data_frame[sentiment].as_matrix()
    return feature_matrix,sentiment_matrix

# %%
feature_matrix_train,sentiment_train = get_numpy_data(data_train,
                                                     important_words,
                                                     'sentiment')
feature_matrix_valid,sentiment_valid = get_numpy_data(data_validation,
                                                     important_words,
                                                     'sentiment')

# %%
print "feature_matrix_train",feature_matrix_train.shape
print "feature_matrix_valid",feature_matrix_valid.shape
# Out:
# feature_matrix_train (42361, 194)
# feature_matrix_valid (10711, 194)

# %%
def get_prob(feature_matrix,weight):
    score = np.dot(feature_matrix,weight)
    return 1/(1+np.exp(-score))

# %%
def feature_derivative(errors,feature):
    return np.dot(errors.transpose(),feature)

# %%
def feature_derivative_with_L2(errors,feature,coeff,l2_penalty,
                              feature_is_constant):
    old_derivative = feature_derivative(errors,feature)
    l2_term = 2*l2_penalty*coeff
    l2_term[0] = 0
    new_derivative = old_derivative - l2_term
    return new_derivative

# %%
def compute_log_likelihood_with_L2(feature_matrix, sentiment, coefficients, l2_penalty):
    indicator = (sentiment==+1)
    scores = np.dot(feature_matrix, coefficients)
    
    lp = np.sum((indicator-1)*scores - np.log(1. + np.exp(-scores))) - l2_penalty*np.sum(coefficients[1:]**2)
    
    return lp

# %%
def logistic_regression_with_l2(feature_matrix,sentiment,initial_coeff,
                               step_size,l2_penalty,max_iter):
    for i in range(max_iter):
        prediction = get_prob(feature_matrix,initial_coeff)
        y = map(lambda x :1 if x ==1 else 0,sentiment)
        error = y - prediction
        grad = feature_derivative_with_L2(error,feature_matrix,initial_coeff,l2_penalty,
                                         'ones')
        initial_coeff = initial_coeff + step_size * grad
        l = compute_log_likelihood_with_L2(feature_matrix,sentiment,
                                          initial_coeff,l2_penalty)
        if i%50 == 0:
            print "l2_penalty : ",l2_penalty,"Iteration : ",i,"Likelihood : ",l
    return initial_coeff

# %%
feature_matrix = feature_matrix_train
sentiment = sentiment_train
initial_coeff = np.array([0]*194)
step_size = 5e-6
max_iter = 501
l2 = [0,4,10,1e2,1e3,1e5]
W = [logistic_regression_with_l2(feature_matrix,sentiment,initial_coeff,
                                step_size,l,max_iter) for l in l2]
# Out:
# l2_penalty :  0 Iteration :  0 Likelihood :  -29179.391383
# l2_penalty :  0 Iteration :  50 Likelihood :  -24509.6359003
# l2_penalty :  0 Iteration :  100 Likelihood :  -22794.9097492
# l2_penalty :  0 Iteration :  150 Likelihood :  -21870.7744764
# l2_penalty :  0 Iteration :  200 Likelihood :  -21283.2952735
# l2_penalty :  0 Iteration :  250 Likelihood :  -20873.799416
# l2_penalty :  0 Iteration :  300 Likelihood :  -20570.9748547
# l2_penalty :  0 Iteration :  350 Likelihood :  -20337.6054165
# l2_penalty :  0 Iteration :  400 Likelihood :  -20152.2146694
# l2_penalty :  0 Iteration :  450 Likelihood :  -20001.4705739
# l2_penalty :  0 Iteration :  500 Likelihood :  -19876.6233341
# l2_penalty :  4 Iteration :  0 Likelihood :  -29179.3950818
# l2_penalty :  4 Iteration :  50 Likelihood :  -24517.5209198
# l2_penalty :  4 Iteration :  100 Likelihood :  -22813.4484458
# l2_penalty :  4 Iteration :  150 Likelihood :  -21899.39001
# l2_penalty :  4 Iteration :  200 Likelihood :  -21321.1416479
# l2_penalty :  4 Iteration :  250 Likelihood :  -20920.0800349
# l2_penalty :  4 Iteration :  300 Likelihood :  -20624.9863444
# l2_penalty :  4 Iteration :  350 Likelihood :  -20398.733276
# l2_penalty :  4 Iteration :  400 Likelihood :  -20219.9204884
# l2_penalty :  4 Iteration :  450 Likelihood :  -20075.2794804
# l2_penalty :  4 Iteration :  500 Likelihood :  -19956.1134178
# l2_penalty :  10 Iteration :  0 Likelihood :  -29179.4006298
# l2_penalty :  10 Iteration :  50 Likelihood :  -24529.3118803
# l2_penalty :  10 Iteration :  100 Likelihood :  -22841.0899514
# l2_penalty :  10 Iteration :  150 Likelihood :  -21941.9355351
# l2_penalty :  10 Iteration :  200 Likelihood :  -21377.2559533
# l2_penalty :  10 Iteration :  250 Likelihood :  -20988.5139426
# l2_penalty :  10 Iteration :  300 Likelihood :  -20704.6399543
# l2_penalty :  10 Iteration :  350 Likelihood :  -20488.6475872
# l2_penalty :  10 Iteration :  400 Likelihood :  -20319.2568531
# l2_penalty :  10 Iteration :  450 Likelihood :  -20183.299736
# l2_penalty :  10 Iteration :  500 Likelihood :  -20072.1632172
# l2_penalty :  100.0 Iteration :  0 Likelihood :  -29179.4838512
# l2_penalty :  100.0 Iteration :  50 Likelihood :  -24701.036982
# l2_penalty :  100.0 Iteration :  100 Likelihood :  -23232.8819202
# l2_penalty :  100.0 Iteration :  150 Likelihood :  -22529.6074771
# l2_penalty :  100.0 Iteration :  200 Likelihood :  -22133.5072653
# l2_penalty :  100.0 Iteration :  250 Likelihood :  -21889.4075773
# l2_penalty :  100.0 Iteration :  300 Likelihood :  -21730.0395749
# l2_penalty :  100.0 Iteration :  350 Likelihood :  -21621.7170537
# l2_penalty :  100.0 Iteration :  400 Likelihood :  -21545.8757214
# l2_penalty :  100.0 Iteration :  450 Likelihood :  -21491.5583925
# l2_penalty :  100.0 Iteration :  500 Likelihood :  -21451.9555139
# l2_penalty :  1000.0 Iteration :  0 Likelihood :  -29180.3160647
# l2_penalty :  1000.0 Iteration :  50 Likelihood :  -25995.9690315
# l2_penalty :  1000.0 Iteration :  100 Likelihood :  -25614.8146871
# l2_penalty :  1000.0 Iteration :  150 Likelihood :  -25549.3979151
# l2_penalty :  1000.0 Iteration :  200 Likelihood :  -25536.2099892
# l2_penalty :  1000.0 Iteration :  250 Likelihood :  -25533.276376
# l2_penalty :  1000.0 Iteration :  300 Likelihood :  -25532.5769122
# l2_penalty :  1000.0 Iteration :  350 Likelihood :  -25532.4012939
# l2_penalty :  1000.0 Iteration :  400 Likelihood :  -25532.3554376
# l2_penalty :  1000.0 Iteration :  450 Likelihood :  -25532.3430989
# l2_penalty :  1000.0 Iteration :  500 Likelihood :  -25532.3397005
# l2_penalty :  100000.0 Iteration :  0 Likelihood :  -29271.8595512
# l2_penalty :  100000.0 Iteration :  50 Likelihood :  -29271.1807825
# l2_penalty :  100000.0 Iteration :  100 Likelihood :  -29271.1766975
# l2_penalty :  100000.0 Iteration :  150 Likelihood :  -29271.1766688
# l2_penalty :  100000.0 Iteration :  200 Likelihood :  -29271.1766686
# l2_penalty :  100000.0 Iteration :  250 Likelihood :  -29271.1766686
# l2_penalty :  100000.0 Iteration :  300 Likelihood :  -29271.1766686
# l2_penalty :  100000.0 Iteration :  350 Likelihood :  -29271.1766686
# l2_penalty :  100000.0 Iteration :  400 Likelihood :  -29271.1766686
# l2_penalty :  100000.0 Iteration :  450 Likelihood :  -29271.1766686
# l2_penalty :  100000.0 Iteration :  500 Likelihood :  -29271.1766686

# %% [markdown]
# # Quiz 1)
#
# ## Likelihood increase

# %%
important_words = list(pd.read_json('../data/important_words.json')[0])
important_words = ['intercept'] + important_words
Coefficients = pd.DataFrame()
Coefficients['words'] = important_words
i = 0
for l in l2:
    Coefficients[l] = W[i]
    i+=1
Coefficients
# Out:
#           words         0         4        10     100.0    1000.0  100000.0
# 0     intercept -0.063742 -0.063143 -0.062256 -0.050438  0.000054  0.011362
# 1          baby  0.074073  0.073994  0.073877  0.072360  0.059752  0.001784
# 2           one  0.012753  0.012495  0.012115  0.007247 -0.008761 -0.001827
# 3         great  0.801625  0.796897  0.789935  0.701425  0.376012  0.008950
# 4          love  1.058554  1.050856  1.039529  0.896644  0.418354  0.009042
# 5           use -0.000104  0.000163  0.000556  0.005481  0.017326  0.000418
# 6         would -0.287021 -0.286027 -0.284564 -0.265993 -0.188662 -0.008127
# 7          like -0.003384 -0.003442 -0.003527 -0.004635 -0.007043 -0.000827
# 8          easy  0.984559  0.977600  0.967362  0.838245  0.401904  0.008808
# 9        little  0.524419  0.521385  0.516917  0.460235  0.251221  0.005941
# 10         seat -0.086968 -0.086125 -0.084883 -0.069109 -0.017718  0.000611
# 11          old  0.208912  0.207749  0.206037  0.184332  0.105074  0.002741
# 12         well  0.453866  0.450969  0.446700  0.392304  0.194926  0.003945
# 13          get -0.196835 -0.196100 -0.195017 -0.181251 -0.122728 -0.004578
# 14         also  0.158163  0.157246  0.155899  0.139153  0.080918  0.001929
# 19        product -0.263330 -0.262328 -0.260854 -0.242391 -0.167962 -0.006211
# 146        design -0.258925 -0.256554 -0.253061 -0.208564 -0.068266 -0.001063
# 107       reviews -0.250486 -0.248603 -0.245831 -0.210734 -0.093923 -0.002153
# ..            ...       ...       ...       ...       ...       ...       ...
# 72            set  0.174279  0.172850  0.170744  0.143903  0.055060  0.000756
# 95           play  0.179602  0.178205  0.176147  0.150117  0.065077  0.001225
# 56           size  0.181497  0.180218  0.178334  0.154415  0.071671  0.001376
# 28          still  0.188508  0.187071  0.184955  0.158163  0.068491  0.000976
# 27            car  0.193364  0.191904  0.189754  0.162531  0.072719  0.001765
# 87           kids  0.199409  0.197789  0.195403  0.165009  0.064353  0.001040
# 89          night  0.206879  0.205086  0.202443  0.168821  0.058443  0.000378
# 11            old  0.208912  0.207749  0.206037  0.184332  0.105074  0.002741
# 58           need  0.226304  0.224375  0.221533  0.185408  0.068125  0.000858
# 81            lot  0.246091  0.243969  0.240843  0.200990  0.071774  0.000990
# 51           room  0.260320  0.258217  0.255120  0.215833  0.086121  0.001163
# 21       daughter  0.263418  0.261775  0.259357  0.228685  0.117158  0.002401
# 45          price  0.265797  0.263600  0.260361  0.219067  0.081838  0.001077
# 71        without  0.268534  0.266144  0.262622  0.217730  0.072816  0.000796
# 84    comfortable  0.333592  0.330807  0.326704  0.274494  0.104824  0.001797
# 88            bit  0.335758  0.332914  0.328724  0.275314  0.100845  0.001510
# 52          works  0.339155  0.336369  0.332262  0.279768  0.104500  0.001509
# 31      recommend  0.358310  0.355582  0.351565  0.300471  0.125289  0.001833
# 48           soft  0.361783  0.359052  0.355030  0.303757  0.128587  0.002331
# 35           nice  0.429394  0.426024  0.421061  0.357813  0.144894  0.002415
# 12           well  0.453866  0.450969  0.446700  0.392304  0.194926  0.003945
# 91           fits  0.487652  0.483429  0.477205  0.397765  0.141241  0.002309
# 9          little  0.524419  0.521385  0.516917  0.460235  0.251221  0.005941
# 76           best  0.535034  0.530265  0.523236  0.433526  0.145591  0.001974
# 83          happy  0.557395  0.552484  0.545245  0.452800  0.154087  0.002159
# 3           great  0.801625  0.796897  0.789935  0.701425  0.376012  0.008950
# 34        perfect  0.835693  0.828555  0.818038  0.684143  0.250614  0.003989
# 8            easy  0.984559  0.977600  0.967362  0.838245  0.401904  0.008808
# 23          loves  1.052484  1.043903  1.031265  0.870794  0.345870  0.006150
# 4            love  1.058554  1.050856  1.039529  0.896644  0.418354  0.009042
#
# [194 rows x 7 columns]

# %%
negative_words_table = Coefficients[['words',0]][0:5]
positive_words_table = Coefficients[['words',0]][-5:]
print positive_words_table
print negative_words_table
# Out:
#       words         0
# 3     great  0.801625
# 34  perfect  0.835693
# 8      easy  0.984559
# 23    loves  1.052484
# 4      love  1.058554
#             words         0
# 106  disappointed -0.955437
# 97          money -0.768793
# 114        return -0.742085
# 113         waste -0.617809
# 169      returned -0.572707

# %%
positive_words = positive_words_table['words']
negative_words = negative_words_table['words']

# %%
for i in l2:
    data_train['prediction'+str(i)] = np.do
